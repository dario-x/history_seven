# %%
# %%capture

#standard libraries
import os
import pandas as pd
import numpy as np
import regex as re

#for visuals
import matplotlib.pyplot as plt

#for coordinate conversion
# !pip install utm
import utm

#for scaling the coordinates
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler(feature_range=(0,3.4))

# %%
df = pd.read_csv('../data/district_data.csv', sep= ";")


plt.scatter( x=df["LONG"], y=df["LAT"])

# %%
import pyproj
from shapely.geometry import Point

# Create a projection 
# in Web Mercator the same that leaflet uses which was used for the 2D application
project = pyproj.Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

row_counter = 0
x_coordinates = []
y_coordinates = []
for i in df.iterrows():
    
    x_y = project.transform(df.iloc[row_counter]["LONG"], df.iloc[row_counter]["LAT"])
    x = x_y[0]
    y = x_y[1]
    x_coordinates.append(x)
    y_coordinates.append(y)
    row_counter += 1
    
df["X_coord"] = x_coordinates
df["Y_coord"] = y_coordinates


df[['X_coord', 'Y_coord']] = scaler.fit_transform(df[['X_coord', 'Y_coord']])
df["Y_coord"]  =  df["Y_coord"]+0.5
df["X_coord"]  =  df["X_coord"]-1.7

plt.scatter(df["X_coord"], df["Y_coord"])

# %%
df["scale"] = 0

df.loc[df["TYPE"] == "church", "scale"] = "0.018 0.036 0.018"
df.loc[df["TYPE"] == "farm", "scale"] = "0.014 0.0145 0.014"
df.loc[df["TYPE"] == "settlement", "scale"] = "0.2 0.2 0.2"
df.loc[df["TYPE"] == "building", "scale"] = "0.003 0.003 0.003"
df.loc[df["TYPE"] == "cinema", "scale"] = "0.02 0.02 0.02"
df.loc[df["TYPE"] == "coffee_house", "scale"] = "0.002 0.002 0.002"
df.loc[df["TYPE"] == "health_institution", "scale"] = "0.003 0.003 0.003"
df.loc[df["TYPE"] == "ns_institution", "scale"] = "0.1 0.1 0.1"
df.loc[df["TYPE"] == "park", "scale"] = "0.005 0.005 0.005"
df.loc[df["TYPE"] == "school", "scale"] = "0.00007 0.00007 0.00007"
df.loc[df["TYPE"] == "statue", "scale"] = "0.012 0.012 0.012"
df.loc[df["TYPE"] == "theatre", "scale"] = "0.04 0.04 0.04"

df["delay_appearance"] = (df["DATUM_VON"] -1211) *1000
df["delay_vanishing"] = (df["DATUM_BIS"] -1211) *1000

# %%
df
# Out:
#                                     SEITENNAME               TYPE  DATUM_VON  \
# 0                           Dorothea-Neff-Park               park       2007
# 1    Johannes-Nepomuk-Statue (7, Ulrichsplatz)             statue       1750
# 3                    Zum St. Ulrich (Apotheke)  health_insitution       1713
# 4         Zum goldenen Elefanten (7, Apotheke)  health_insitution       1783
# 5                               Löwinger-Bühne           building       1749
# ..                                         ...                ...        ...
# 226                    VS Neustiftgasse 98-102             school       1887
# 227                          VS Zollergasse 41             school       1883
# 228                      Wohnhaus Bernardgasse           building       1925
# 229                     Wohnhaus Neustiftgasse           building       1925
# 232                              Non Stop Kino             cinema       1913
#
#      DATUM_BIS      BENANNT_NACH                       STREET  DISTRICT  \
# 0            0     Dorothea Neff                Bandgasse 5/1         7
# 1            0  Johannes Nepomuk  St.-Ulrichs-Platz 3(PFARRE)         7
# 3            0               NaN                 Burggasse 22         7
# 4            0               NaN          Siebensterngasse 20         7
# 5         1975               NaN             Neubaugasse 36/1         7
# ..         ...               ...                          ...       ...
# 226          0               NaN     Neustiftgasse 98(SCHULE)         7
# 227       1957               NaN       Zollergasse 41(SCHULE)         7
# 228          0      Bernardgasse            Bernardgasse 38/1         7
# 229          0     Neustiftgasse          Neustiftgasse 143/1         7
# 232          0               NaN    Museumsplatz 1(HOF E3/10)         7
#
#                                             SHAPE  \
# 0     POINT (16.345714016431135 48.2005820408563)
# 1    POINT (16.352570150538384 48.20476086708961)
# 3    POINT (16.35302526327066 48.204289915815366)
# 4       POINT (16.35432653570176 48.202555822982)
# 5      POINT (16.3494000247669 48.20136633307758)
# ..                                            ...
# 226  POINT (16.341664446696182 48.20601124790739)
# 227   POINT (16.35017001636822 48.20179904084544)
# 228   POINT (16.33888602578309 48.20732831553085)
# 229  POINT (16.338929543731112 48.20597555396534)
# 232   POINT (16.36021437700146 48.20173788535905)
#
#                                               WEBLINK1       LONG        LAT  \
# 0    https://www.geschichtewiki.wien.gv.at/?curid=3...  16.345714  48.200582
# 1    https://www.geschichtewiki.wien.gv.at/?curid=1...  16.352570  48.204761
# 3    https://www.geschichtewiki.wien.gv.at/?curid=2...  16.353025  48.204290
# 4    https://www.geschichtewiki.wien.gv.at/?curid=1...  16.354327  48.202556
# 5    https://www.geschichtewiki.wien.gv.at/?curid=2...  16.349400  48.201366
# ..                                                 ...        ...        ...
# 226  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.341664  48.206011
# 227  https://www.geschichtewiki.wien.gv.at/?curid=7...  16.350170  48.201799
# 228  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.338886  48.207328
# 229  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.338930  48.205976
# 232  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.360214  48.201738
#
#       X_coord   Y_coord                    scale  delay_appearance  \
# 0   -0.533594  1.738810        0.005 0.005 0.005            796000
# 1    0.522505  2.920090        0.012 0.012 0.012            539000
# 3    0.592610  2.786956                        0            502000
# 4    0.793054  2.296751                        0            572000
# 5    0.034188  1.960508        0.003 0.003 0.003            538000
# ..        ...       ...                      ...               ...
# 226 -1.157378  3.273570  0.00007 0.00007 0.00007            676000
# 227  0.152796  2.082824  0.00007 0.00007 0.00007            672000
# 228 -1.585358  3.645910        0.003 0.003 0.003            714000
# 229 -1.578654  3.263479        0.003 0.003 0.003            714000
# 232  1.700000  2.065537           0.02 0.02 0.02            702000
#
#      delay_vanishing
# 0           -1211000
# 1           -1211000
# 3           -1211000
# 4           -1211000
# 5             764000
# ..               ...
# 226         -1211000
# 227           746000
# 228         -1211000
# 229         -1211000
# 232         -1211000
#
# [179 rows x 16 columns]

# %%
for i, n in enumerate(df.iterrows()):
    code='''<a-entity gltf-model="#{0}"   
    position="{1} -1 {2}" 
    animation="property: position; to:{1} 0.3 {2}  
    dur: 1000; easing: linear; loop: false; delay:{3}" '''.format(str(df.iloc[i]["TYPE"]), 
                                                                  str(df.iloc[i]["X_coord"]), 
                                                                  str(-df.iloc[i]["Y_coord"]), 
                                                                  str(df.iloc[i]["delay_appearance"]))
    
    if df.iloc[i]["delay_vanishing"] > 0:
        code+='''
        animation__2="property: position; to:{0} -1 {1}
        dur: 1000; easing: linear; loop: false; delay:{2}" '''.format(str(df.iloc[i]["X_coord"]),
                                                                   str(-df.iloc[i]["Y_coord"]),
                                                                   str(df.iloc[i]["delay_vanishing"]))
    else:
        pass
    
    if df.iloc[i]["TYPE"] =="church":
        code+=''' rotation="0 -40 0" '''
    else:
        pass
            
    
    code+='scale="{0}"></a-entity>'.format(str(df.iloc[i]["scale"]))
    print(code)
# Out:
# <a-entity gltf-model="#park"
#     position="-0.5335935804843757 -1 -1.7388099749714456"
#     animation="property: position; to:-0.5335935804843757 0.3 -1.7388099749714456
#     dur: 1000; easing: linear; loop: false; delay:796000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#statue"
#     position="0.522505476819606 -1 -2.920090252226146"
#     animation="property: position; to:0.522505476819606 0.3 -2.920090252226146
#     dur: 1000; easing: linear; loop: false; delay:539000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="0.5926097250742715 -1 -2.7869558368456637"
#     animation="property: position; to:0.5926097250742715 0.3 -2.7869558368456637
#     dur: 1000; easing: linear; loop: false; delay:502000" scale="0"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="0.793053964682531 -1 -2.2967512680716027"
#     animation="property: position; to:0.793053964682531 0.3 -2.2967512680716027
#     dur: 1000; easing: linear; loop: false; delay:572000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.3 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:538000"
#         animation__2="property: position; to:0.034188476826602754 -1 -1.960508170472167
#         dur: 1000; easing: linear; loop: false; delay:764000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7889071580510063 -1 -3.145167100974504"
#     animation="property: position; to:0.7889071580510063 0.3 -3.145167100974504
#     dur: 1000; easing: linear; loop: false; delay:490000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.773365142685907 -1 -3.2574938744073734"
#     animation="property: position; to:0.773365142685907 0.3 -3.2574938744073734
#     dur: 1000; easing: linear; loop: false; delay:600000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.327482584469908 -1 -2.631229073753275"
#     animation="property: position; to:1.327482584469908 0.3 -2.631229073753275
#     dur: 1000; easing: linear; loop: false; delay:751000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="0.7723591048245908 -1 -2.765829985441087"
#     animation="property: position; to:0.7723591048245908 0.3 -2.765829985441087
#     dur: 1000; easing: linear; loop: false; delay:713000"
#         animation__2="property: position; to:0.7723591048245908 -1 -2.765829985441087
#         dur: 1000; easing: linear; loop: false; delay:796000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7723591048245908 -1 -2.765829985441087"
#     animation="property: position; to:0.7723591048245908 0.3 -2.765829985441087
#     dur: 1000; easing: linear; loop: false; delay:712000"
#         animation__2="property: position; to:0.7723591048245908 -1 -2.765829985441087
#         dur: 1000; easing: linear; loop: false; delay:796000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.33060038568719397 -1 -2.2393187284724263"
#     animation="property: position; to:0.33060038568719397 0.3 -2.2393187284724263
#     dur: 1000; easing: linear; loop: false; delay:727000"
#         animation__2="property: position; to:0.33060038568719397 -1 -2.2393187284724263
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.3 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:734000"
#         animation__2="property: position; to:-0.5895969164937014 -1 -1.6486238450888777
#         dur: 1000; easing: linear; loop: false; delay:744000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5316938722810847 -1 -2.574248753955544"
#     animation="property: position; to:1.5316938722810847 0.3 -2.574248753955544
#     dur: 1000; easing: linear; loop: false; delay:790000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.20440577134722848 -1 -3.173233387484288"
#     animation="property: position; to:0.20440577134722848 0.3 -3.173233387484288
#     dur: 1000; easing: linear; loop: false; delay:692000"
#         animation__2="property: position; to:0.20440577134722848 -1 -3.173233387484288
#         dur: 1000; easing: linear; loop: false; delay:721000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.2587915687801796 -1 -1.2223795748886914"
#     animation="property: position; to:-0.2587915687801796 0.3 -1.2223795748886914
#     dur: 1000; easing: linear; loop: false; delay:786000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#church"
#     position="0.5226300878328403 -1 -2.9216410405897477"
#     animation="property: position; to:0.5226300878328403 0.3 -2.9216410405897477
#     dur: 1000; easing: linear; loop: false; delay:0"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#church"
#     position="0.7951621770833299 -1 -3.126758547488862"
#     animation="property: position; to:0.7951621770833299 0.3 -3.126758547488862
#     dur: 1000; easing: linear; loop: false; delay:626000"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#statue"
#     position="-1.630337950055673 -1 -1.993215932561725"
#     animation="property: position; to:-1.630337950055673 0.3 -1.993215932561725
#     dur: 1000; easing: linear; loop: false; delay:690000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.22787751781534094 -1 -0.9483957975789963"
#     animation="property: position; to:-0.22787751781534094 0.3 -0.9483957975789963
#     dur: 1000; easing: linear; loop: false; delay:744000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.801312300420068 -1 -2.4594264942916197"
#     animation="property: position; to:0.801312300420068 0.3 -2.4594264942916197
#     dur: 1000; easing: linear; loop: false; delay:755000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.5983668810243217 -1 -1.8420095854235115"
#     animation="property: position; to:0.5983668810243217 0.3 -1.8420095854235115
#     dur: 1000; easing: linear; loop: false; delay:635000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.2090191980143572 -1 -0.6864117174936837"
#     animation="property: position; to:-1.2090191980143572 0.3 -0.6864117174936837
#     dur: 1000; easing: linear; loop: false; delay:414000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5274227794359831 -1 -2.3134910681910696"
#     animation="property: position; to:1.5274227794359831 0.3 -2.3134910681910696
#     dur: 1000; easing: linear; loop: false; delay:790000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.3 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:780000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#coffe_house"
#     position="0.004354561949003299 -1 -2.0027652448643494"
#     animation="property: position; to:0.004354561949003299 0.3 -2.0027652448643494
#     dur: 1000; easing: linear; loop: false; delay:591000"
#         animation__2="property: position; to:0.004354561949003299 -1 -2.0027652448643494
#         dur: 1000; easing: linear; loop: false; delay:700000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7951621770833299 -1 -3.126758547488862"
#     animation="property: position; to:0.7951621770833299 0.3 -3.126758547488862
#     dur: 1000; easing: linear; loop: false; delay:314000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="0.8727650368094146 -1 -3.450200091874649"
#     animation="property: position; to:0.8727650368094146 0.3 -3.450200091874649
#     dur: 1000; easing: linear; loop: false; delay:771000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#coffe_house"
#     position="1.0771782721461023 -1 -3.0649185276142816"
#     animation="property: position; to:1.0771782721461023 0.3 -3.0649185276142816
#     dur: 1000; easing: linear; loop: false; delay:595000"
#         animation__2="property: position; to:1.0771782721461023 -1 -3.0649185276142816
#         dur: 1000; easing: linear; loop: false; delay:654000" scale="0"></a-entity>
# <a-entity gltf-model="#statue"
#     position="1.182687719873502 -1 -3.179937387443715"
#     animation="property: position; to:1.182687719873502 0.3 -3.179937387443715
#     dur: 1000; easing: linear; loop: false; delay:687000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.3 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:756000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#church"
#     position="-1.3506064976701964 -1 -0.7311237930207426"
#     animation="property: position; to:-1.3506064976701964 0.3 -0.7311237930207426
#     dur: 1000; easing: linear; loop: false; delay:649000"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.3 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:761000"
#         animation__2="property: position; to:-0.5895969164937014 -1 -1.6486238450888777
#         dur: 1000; easing: linear; loop: false; delay:778000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5316938722810847 -1 -2.574248753955544"
#     animation="property: position; to:1.5316938722810847 0.3 -2.574248753955544
#     dur: 1000; easing: linear; loop: false; delay:793000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="1.6571220611388526 -1 -2.7346934541346855"
#     animation="property: position; to:1.6571220611388526 0.3 -2.7346934541346855
#     dur: 1000; easing: linear; loop: false; delay:681000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#statue"
#     position="-1.6309540331983043 -1 -1.9926505785570043"
#     animation="property: position; to:-1.6309540331983043 0.3 -1.9926505785570043
#     dur: 1000; easing: linear; loop: false; delay:690000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#church"
#     position="1.042821979774817 -1 -1.751530267760245"
#     animation="property: position; to:1.042821979774817 0.3 -1.751530267760245
#     dur: 1000; easing: linear; loop: false; delay:528000"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.8985159330115493 -1 -1.363442594787557"
#     animation="property: position; to:-0.8985159330115493 0.3 -1.363442594787557
#     dur: 1000; easing: linear; loop: false; delay:695000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#church"
#     position="-0.6871686152619076 -1 -2.026289039229596"
#     animation="property: position; to:-0.6871686152619076 0.3 -2.026289039229596
#     dur: 1000; easing: linear; loop: false; delay:573000"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.563504241143346 -1 -1.9367417133580602"
#     animation="property: position; to:-1.563504241143346 0.3 -1.9367417133580602
#     dur: 1000; easing: linear; loop: false; delay:719000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7365133229662206 -1 -3.1230635635311046"
#     animation="property: position; to:0.7365133229662206 0.3 -3.1230635635311046
#     dur: 1000; easing: linear; loop: false; delay:689000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.652480102499976 -1 -1.2792946541267156"
#     animation="property: position; to:-0.652480102499976 0.3 -1.2792946541267156
#     dur: 1000; easing: linear; loop: false; delay:628000"
#         animation__2="property: position; to:-0.652480102499976 -1 -1.2792946541267156
#         dur: 1000; easing: linear; loop: false; delay:665000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.652480102499976 -1 -1.2792946541267156"
#     animation="property: position; to:-0.652480102499976 0.3 -1.2792946541267156
#     dur: 1000; easing: linear; loop: false; delay:596000"
#         animation__2="property: position; to:-0.652480102499976 -1 -1.2792946541267156
#         dur: 1000; easing: linear; loop: false; delay:665000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.32704071675352675 -1 -0.8687853252431523"
#     animation="property: position; to:-0.32704071675352675 0.3 -0.8687853252431523
#     dur: 1000; easing: linear; loop: false; delay:690000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.9101162396734253 -1 -3.052993770694229"
#     animation="property: position; to:-0.9101162396734253 0.3 -3.052993770694229
#     dur: 1000; easing: linear; loop: false; delay:701000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.03446277810480747 -1 -1.8151114938991668"
#     animation="property: position; to:-0.03446277810480747 0.3 -1.8151114938991668
#     dur: 1000; easing: linear; loop: false; delay:700000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.6228303374316966 -1 -1.9821577774764592"
#     animation="property: position; to:1.6228303374316966 0.3 -1.9821577774764592
#     dur: 1000; easing: linear; loop: false; delay:687000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#coffe_house"
#     position="-1.3856465994114842 -1 -0.5"
#     animation="property: position; to:-1.3856465994114842 0.3 -0.5
#     dur: 1000; easing: linear; loop: false; delay:679000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.24011645174623486 -1 -2.712072034826633"
#     animation="property: position; to:0.24011645174623486 0.3 -2.712072034826633
#     dur: 1000; easing: linear; loop: false; delay:663000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.3 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:475000"
#         animation__2="property: position; to:0.034188476826602754 -1 -1.960508170472167
#         dur: 1000; easing: linear; loop: false; delay:543000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.3258082231092885 -1 -2.240747680698405"
#     animation="property: position; to:-1.3258082231092885 0.3 -2.240747680698405
#     dur: 1000; easing: linear; loop: false; delay:610000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.5964025854243118 -1 -2.9547859666399745"
#     animation="property: position; to:-1.5964025854243118 0.3 -2.9547859666399745
#     dur: 1000; easing: linear; loop: false; delay:683000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.5780884297308149 -1 -2.8189419902810187"
#     animation="property: position; to:0.5780884297308149 0.3 -2.8189419902810187
#     dur: 1000; easing: linear; loop: false; delay:122000"
#         animation__2="property: position; to:0.5780884297308149 -1 -2.8189419902810187
#         dur: 1000; easing: linear; loop: false; delay:318000" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.3088682391300608 -1 -1.583421683702909"
#     animation="property: position; to:-1.3088682391300608 0.3 -1.583421683702909
#     dur: 1000; easing: linear; loop: false; delay:679000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5316938722810847 -1 -2.574248753955544"
#     animation="property: position; to:1.5316938722810847 0.3 -2.574248753955544
#     dur: 1000; easing: linear; loop: false; delay:508000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.3446170751629325 -1 -2.034872139340223"
#     animation="property: position; to:0.3446170751629325 0.3 -2.034872139340223
#     dur: 1000; easing: linear; loop: false; delay:687000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.7257258807346261 -1 -1.316494827349743"
#     animation="property: position; to:-0.7257258807346261 0.3 -1.316494827349743
#     dur: 1000; easing: linear; loop: false; delay:751000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.6669570442156327 -1 -1.5798312642727979"
#     animation="property: position; to:-1.6669570442156327 0.3 -1.5798312642727979
#     dur: 1000; easing: linear; loop: false; delay:789000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.6649643795992233 -1 -1.7230535996604885"
#     animation="property: position; to:-1.6649643795992233 0.3 -1.7230535996604885
#     dur: 1000; easing: linear; loop: false; delay:662000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.09985499903286832 -1 -2.8060070770516177"
#     animation="property: position; to:-0.09985499903286832 0.3 -2.8060070770516177
#     dur: 1000; easing: linear; loop: false; delay:690000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.4556659254523765 -1 -2.1028595911266166"
#     animation="property: position; to:-0.4556659254523765 0.3 -2.1028595911266166
#     dur: 1000; easing: linear; loop: false; delay:583000"
#         animation__2="property: position; to:-0.4556659254523765 -1 -2.1028595911266166
#         dur: 1000; easing: linear; loop: false; delay:636000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="-1.7 -1 -3.8931960230147524"
#     animation="property: position; to:-1.7 0.3 -3.8931960230147524
#     dur: 1000; easing: linear; loop: false; delay:663000"
#         animation__2="property: position; to:-1.7 -1 -3.8931960230147524
#         dur: 1000; easing: linear; loop: false; delay:698000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.32988853991964784 -1 -3.119214917966019"
#     animation="property: position; to:-0.32988853991964784 0.3 -3.119214917966019
#     dur: 1000; easing: linear; loop: false; delay:787000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.38083676618980467 -1 -3.151785286321683"
#     animation="property: position; to:0.38083676618980467 0.3 -3.151785286321683
#     dur: 1000; easing: linear; loop: false; delay:418000"
#         animation__2="property: position; to:0.38083676618980467 -1 -3.151785286321683
#         dur: 1000; easing: linear; loop: false; delay:577000" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#theatre"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.3 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:721000" scale="0.04 0.04 0.04"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.7236451632031276 -1 -2.115762496212483"
#     animation="property: position; to:-0.7236451632031276 0.3 -2.115762496212483
#     dur: 1000; easing: linear; loop: false; delay:701000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.5746565384359201 -1 -2.864882557796591"
#     animation="property: position; to:0.5746565384359201 0.3 -2.864882557796591
#     dur: 1000; easing: linear; loop: false; delay:539000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.9124842822705432 -1 -2.122015459166505"
#     animation="property: position; to:0.9124842822705432 0.3 -2.122015459166505
#     dur: 1000; easing: linear; loop: false; delay:535000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="-1.2672724427595312 -1 -0.9473535074139363"
#     animation="property: position; to:-1.2672724427595312 0.3 -0.9473535074139363
#     dur: 1000; easing: linear; loop: false; delay:670000"
#         animation__2="property: position; to:-1.2672724427595312 -1 -0.9473535074139363
#         dur: 1000; easing: linear; loop: false; delay:806000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8790314071973626 -1 -2.7114951591593126"
#     animation="property: position; to:0.8790314071973626 0.3 -2.7114951591593126
#     dur: 1000; easing: linear; loop: false; delay:529000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0322810520986423 -1 -3.215949434070353"
#     animation="property: position; to:1.0322810520986423 0.3 -3.215949434070353
#     dur: 1000; easing: linear; loop: false; delay:501000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.12514151282466623 -1 -3.0936517907448433"
#     animation="property: position; to:-0.12514151282466623 0.3 -3.0936517907448433
#     dur: 1000; easing: linear; loop: false; delay:700000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.4527148630580087 -1 -2.5014759012028662"
#     animation="property: position; to:1.4527148630580087 0.3 -2.5014759012028662
#     dur: 1000; easing: linear; loop: false; delay:508000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8259057015396138 -1 -3.073029479402976"
#     animation="property: position; to:0.8259057015396138 0.3 -3.073029479402976
#     dur: 1000; easing: linear; loop: false; delay:501000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.0967535291881176 -1 -2.058732960247653"
#     animation="property: position; to:-1.0967535291881176 0.3 -2.058732960247653
#     dur: 1000; easing: linear; loop: false; delay:697000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.1139607681736379 -1 -0.5880051651984104"
#     animation="property: position; to:-1.1139607681736379 0.3 -0.5880051651984104
#     dur: 1000; easing: linear; loop: false; delay:700000"
#         animation__2="property: position; to:-1.1139607681736379 -1 -0.5880051651984104
#         dur: 1000; easing: linear; loop: false; delay:785000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.3851237640363252 -1 -3.134674084656581"
#     animation="property: position; to:0.3851237640363252 0.3 -3.134674084656581
#     dur: 1000; easing: linear; loop: false; delay:418000"
#         animation__2="property: position; to:0.3851237640363252 -1 -3.134674084656581
#         dur: 1000; easing: linear; loop: false; delay:577000" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.4553072856454492 -1 -2.2341015704369056"
#     animation="property: position; to:0.4553072856454492 0.3 -2.2341015704369056
#     dur: 1000; easing: linear; loop: false; delay:688000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.985378157708783 -1 -1.886308520770399"
#     animation="property: position; to:0.985378157708783 0.3 -1.886308520770399
#     dur: 1000; easing: linear; loop: false; delay:528000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#theatre"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.3 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:701000" scale="0.04 0.04 0.04"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.010635802991328047 -1 -2.5449215647058736"
#     animation="property: position; to:-0.010635802991328047 0.3 -2.5449215647058736
#     dur: 1000; easing: linear; loop: false; delay:693000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.42069856467678624 -1 -3.3353610051017313"
#     animation="property: position; to:0.42069856467678624 0.3 -3.3353610051017313
#     dur: 1000; easing: linear; loop: false; delay:165000"
#         animation__2="property: position; to:0.42069856467678624 -1 -3.3353610051017313
#         dur: 1000; easing: linear; loop: false; delay:559000" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9796765863291512 -1 -2.3749704562997067"
#     animation="property: position; to:0.9796765863291512 0.3 -2.3749704562997067
#     dur: 1000; easing: linear; loop: false; delay:651000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#church"
#     position="-0.935633169931134 -1 -3.530305719035823"
#     animation="property: position; to:-0.935633169931134 0.3 -3.530305719035823
#     dur: 1000; easing: linear; loop: false; delay:637000"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0049360156083822 -1 -2.367793498618994"
#     animation="property: position; to:1.0049360156083822 0.3 -2.367793498618994
#     dur: 1000; easing: linear; loop: false; delay:685000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9627432482391669 -1 -2.461920369834843"
#     animation="property: position; to:0.9627432482391669 0.3 -2.461920369834843
#     dur: 1000; easing: linear; loop: false; delay:681000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9911224251443855 -1 -2.508816169896818"
#     animation="property: position; to:0.9911224251443855 0.3 -2.508816169896818
#     dur: 1000; easing: linear; loop: false; delay:512000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="1.2207349088451338 -1 -2.9746993255339476"
#     animation="property: position; to:1.2207349088451338 0.3 -2.9746993255339476
#     dur: 1000; easing: linear; loop: false; delay:741000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.6719735025242699 -1 -2.191944855690963"
#     animation="property: position; to:0.6719735025242699 0.3 -2.191944855690963
#     dur: 1000; easing: linear; loop: false; delay:489000"
#         animation__2="property: position; to:0.6719735025242699 -1 -2.191944855690963
#         dur: 1000; easing: linear; loop: false; delay:781000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="-1.6363452532775227 -1 -1.1641516954441613"
#     animation="property: position; to:-1.6363452532775227 0.3 -1.1641516954441613
#     dur: 1000; easing: linear; loop: false; delay:698000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0911675894974906 -1 -2.3895277090941818"
#     animation="property: position; to:1.0911675894974906 0.3 -2.3895277090941818
#     dur: 1000; easing: linear; loop: false; delay:625000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.3856465994114842 -1 -0.5"
#     animation="property: position; to:-1.3856465994114842 0.3 -0.5
#     dur: 1000; easing: linear; loop: false; delay:688000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.2370667771958324 -1 -2.3882916714374005"
#     animation="property: position; to:-1.2370667771958324 0.3 -2.3882916714374005
#     dur: 1000; easing: linear; loop: false; delay:747000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.39009036198940517 -1 -0.8944446373770916"
#     animation="property: position; to:-0.39009036198940517 0.3 -0.8944446373770916
#     dur: 1000; easing: linear; loop: false; delay:689000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.18545606020443306 -1 -1.8002687453845283"
#     animation="property: position; to:0.18545606020443306 0.3 -1.8002687453845283
#     dur: 1000; easing: linear; loop: false; delay:367000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7843439600658713 -1 -2.6936507293012255"
#     animation="property: position; to:0.7843439600658713 0.3 -2.6936507293012255
#     dur: 1000; easing: linear; loop: false; delay:679000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.06227441553010071 -1 -1.4323266238079668"
#     animation="property: position; to:0.06227441553010071 0.3 -1.4323266238079668
#     dur: 1000; easing: linear; loop: false; delay:609000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.854618568044134 -1 -2.2862084000298637"
#     animation="property: position; to:0.854618568044134 0.3 -2.2862084000298637
#     dur: 1000; easing: linear; loop: false; delay:659000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9010954179605506 -1 -2.5775102928128035"
#     animation="property: position; to:0.9010954179605506 0.3 -2.5775102928128035
#     dur: 1000; easing: linear; loop: false; delay:509000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8259057015396138 -1 -3.073029479402976"
#     animation="property: position; to:0.8259057015396138 0.3 -3.073029479402976
#     dur: 1000; easing: linear; loop: false; delay:501000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.17649444538692483 -1 -2.6989684305499395"
#     animation="property: position; to:0.17649444538692483 0.3 -2.6989684305499395
#     dur: 1000; easing: linear; loop: false; delay:477000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="0.5161692319778013 -1 -2.7994296406559442"
#     animation="property: position; to:0.5161692319778013 0.3 -2.7994296406559442
#     dur: 1000; easing: linear; loop: false; delay:502000" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9799814328255707 -1 -2.748531093049678"
#     animation="property: position; to:0.9799814328255707 0.3 -2.748531093049678
#     dur: 1000; easing: linear; loop: false; delay:589000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.42488381358070915 -1 -1.351404340357476"
#     animation="property: position; to:0.42488381358070915 0.3 -1.351404340357476
#     dur: 1000; easing: linear; loop: false; delay:472000"
#         animation__2="property: position; to:0.42488381358070915 -1 -1.351404340357476
#         dur: 1000; easing: linear; loop: false; delay:682000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7663359776081962 -1 -1.9368357728562842"
#     animation="property: position; to:0.7663359776081962 0.3 -1.9368357728562842
#     dur: 1000; easing: linear; loop: false; delay:485000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9582197103039107 -1 -2.7369195059345657"
#     animation="property: position; to:0.9582197103039107 0.3 -2.7369195059345657
#     dur: 1000; easing: linear; loop: false; delay:539000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.13987848378446865 -1 -2.752829894579918"
#     animation="property: position; to:-0.13987848378446865 0.3 -2.752829894579918
#     dur: 1000; easing: linear; loop: false; delay:479000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8934820079000929 -1 -2.6407135518493305"
#     animation="property: position; to:0.8934820079000929 0.3 -2.6407135518493305
#     dur: 1000; easing: linear; loop: false; delay:765000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7439859464746406 -1 -1.5473378591523215"
#     animation="property: position; to:0.7439859464746406 0.3 -1.5473378591523215
#     dur: 1000; easing: linear; loop: false; delay:693000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9389973829700466 -1 -1.6574040254599822"
#     animation="property: position; to:0.9389973829700466 0.3 -1.6574040254599822
#     dur: 1000; easing: linear; loop: false; delay:685000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.443221226069727 -1 -1.9371511747485783"
#     animation="property: position; to:1.443221226069727 0.3 -1.9371511747485783
#     dur: 1000; easing: linear; loop: false; delay:683000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.181142204146272 -1 -2.4690451952465082"
#     animation="property: position; to:1.181142204146272 0.3 -2.4690451952465082
#     dur: 1000; easing: linear; loop: false; delay:679000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.08238854271148743 -1 -1.1010942380544293"
#     animation="property: position; to:0.08238854271148743 0.3 -1.1010942380544293
#     dur: 1000; easing: linear; loop: false; delay:707000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.11984265208293432 -1 -0.974112120034988"
#     animation="property: position; to:-0.11984265208293432 0.3 -0.974112120034988
#     dur: 1000; easing: linear; loop: false; delay:710000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.32704071675352675 -1 -0.8687853252431523"
#     animation="property: position; to:-0.32704071675352675 0.3 -0.8687853252431523
#     dur: 1000; easing: linear; loop: false; delay:708000"
#         animation__2="property: position; to:-0.32704071675352675 -1 -0.8687853252431523
#         dur: 1000; easing: linear; loop: false; delay:719000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.2553372085173577 -1 -2.123470694561547"
#     animation="property: position; to:-1.2553372085173577 0.3 -2.123470694561547
#     dur: 1000; easing: linear; loop: false; delay:710000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.3378879699318531 -1 -2.7585101377535466"
#     animation="property: position; to:-0.3378879699318531 0.3 -2.7585101377535466
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:-0.3378879699318531 -1 -2.7585101377535466
#         dur: 1000; easing: linear; loop: false; delay:789000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.4983008393121964 -1 -2.722820510589372"
#     animation="property: position; to:0.4983008393121964 0.3 -2.722820510589372
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:0.4983008393121964 -1 -2.722820510589372
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="-0.04492711503798996 -1 -2.1229696894915833"
#     animation="property: position; to:-0.04492711503798996 0.3 -2.1229696894915833
#     dur: 1000; easing: linear; loop: false; delay:572000" scale="0"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.90700350034258 -1 -2.5623530251141347"
#     animation="property: position; to:-0.90700350034258 0.3 -2.5623530251141347
#     dur: 1000; easing: linear; loop: false; delay:713000"
#         animation__2="property: position; to:-0.90700350034258 -1 -2.5623530251141347
#         dur: 1000; easing: linear; loop: false; delay:727000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.6719735025242699 -1 -2.191944855690963"
#     animation="property: position; to:0.6719735025242699 0.3 -2.191944855690963
#     dur: 1000; easing: linear; loop: false; delay:489000"
#         animation__2="property: position; to:0.6719735025242699 -1 -2.191944855690963
#         dur: 1000; easing: linear; loop: false; delay:781000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.09410746435360129 -1 -1.1486052951840975"
#     animation="property: position; to:0.09410746435360129 0.3 -1.1486052951840975
#     dur: 1000; easing: linear; loop: false; delay:708000"
#         animation__2="property: position; to:0.09410746435360129 -1 -1.1486052951840975
#         dur: 1000; easing: linear; loop: false; delay:713000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.6064384378771137 -1 -2.749977277519065"
#     animation="property: position; to:-1.6064384378771137 0.3 -2.749977277519065
#     dur: 1000; easing: linear; loop: false; delay:702000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="1.6228303374316966 -1 -1.9821577774764592"
#     animation="property: position; to:1.6228303374316966 0.3 -1.9821577774764592
#     dur: 1000; easing: linear; loop: false; delay:696000"
#         animation__2="property: position; to:1.6228303374316966 -1 -1.9821577774764592
#         dur: 1000; easing: linear; loop: false; delay:698000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.1259588721625733 -1 -1.203960322533021"
#     animation="property: position; to:0.1259588721625733 0.3 -1.203960322533021
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:0.1259588721625733 -1 -1.203960322533021
#         dur: 1000; easing: linear; loop: false; delay:706000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.4736017757738409 -1 -3.900000000001455"
#     animation="property: position; to:-1.4736017757738409 0.3 -3.900000000001455
#     dur: 1000; easing: linear; loop: false; delay:708000"
#         animation__2="property: position; to:-1.4736017757738409 -1 -3.900000000001455
#         dur: 1000; easing: linear; loop: false; delay:715000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.3424744296478821 -1 -3.0074905166802637"
#     animation="property: position; to:0.3424744296478821 0.3 -3.0074905166802637
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:0.3424744296478821 -1 -3.0074905166802637
#         dur: 1000; easing: linear; loop: false; delay:699000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.2988420049934575 -1 -1.9458522008808359"
#     animation="property: position; to:-1.2988420049934575 0.3 -1.9458522008808359
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:-1.2988420049934575 -1 -1.9458522008808359
#         dur: 1000; easing: linear; loop: false; delay:788000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.33060038568719397 -1 -2.2393187284724263"
#     animation="property: position; to:0.33060038568719397 0.3 -2.2393187284724263
#     dur: 1000; easing: linear; loop: false; delay:703000"
#         animation__2="property: position; to:0.33060038568719397 -1 -2.2393187284724263
#         dur: 1000; easing: linear; loop: false; delay:787000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.3378879699318531 -1 -2.7585101377535466"
#     animation="property: position; to:-0.3378879699318531 0.3 -2.7585101377535466
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:-0.3378879699318531 -1 -2.7585101377535466
#         dur: 1000; easing: linear; loop: false; delay:789000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.3378879699318531 -1 -2.7585101377535466"
#     animation="property: position; to:-0.3378879699318531 0.3 -2.7585101377535466
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:-0.3378879699318531 -1 -2.7585101377535466
#         dur: 1000; easing: linear; loop: false; delay:789000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.08238854271148743 -1 -1.1010942380544293"
#     animation="property: position; to:0.08238854271148743 0.3 -1.1010942380544293
#     dur: 1000; easing: linear; loop: false; delay:707000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.012220088742833424 -1 -2.627647403820447"
#     animation="property: position; to:-0.012220088742833424 0.3 -2.627647403820447
#     dur: 1000; easing: linear; loop: false; delay:703000"
#         animation__2="property: position; to:-0.012220088742833424 -1 -2.627647403820447
#         dur: 1000; easing: linear; loop: false; delay:711000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.5987147745442598 -1 -3.564864926654991"
#     animation="property: position; to:-0.5987147745442598 0.3 -3.564864926654991
#     dur: 1000; easing: linear; loop: false; delay:699000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.21184155100472712 -1 -3.3336316674194677"
#     animation="property: position; to:0.21184155100472712 0.3 -3.3336316674194677
#     dur: 1000; easing: linear; loop: false; delay:702000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.8903591795285137 -1 -1.2673521520082431"
#     animation="property: position; to:-0.8903591795285137 0.3 -1.2673521520082431
#     dur: 1000; easing: linear; loop: false; delay:702000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="1.1201161938600308 -1 -2.9619651182983944"
#     animation="property: position; to:1.1201161938600308 0.3 -2.9619651182983944
#     dur: 1000; easing: linear; loop: false; delay:700000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.11984265208293432 -1 -0.974112120034988"
#     animation="property: position; to:-0.11984265208293432 0.3 -0.974112120034988
#     dur: 1000; easing: linear; loop: false; delay:710000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#church"
#     position="-1.2993063083760716 -1 -1.3500075114425272"
#     animation="property: position; to:-1.2993063083760716 0.3 -1.3500075114425272
#     dur: 1000; easing: linear; loop: false; delay:652000"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.1043012435026867 -1 -1.0437391497616773"
#     animation="property: position; to:-1.1043012435026867 0.3 -1.0437391497616773
#     dur: 1000; easing: linear; loop: false; delay:733000"
#         animation__2="property: position; to:-1.1043012435026867 -1 -1.0437391497616773
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#school"
#     position="-0.29221751078621305 -1 -3.4598120160480903"
#     animation="property: position; to:-0.29221751078621305 0.3 -3.4598120160480903
#     dur: 1000; easing: linear; loop: false; delay:654000"
#         animation__2="property: position; to:-0.29221751078621305 -1 -3.4598120160480903
#         dur: 1000; easing: linear; loop: false; delay:724000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="-1.1573775836374807 -1 -3.273569530381792"
#     animation="property: position; to:-1.1573775836374807 0.3 -3.273569530381792
#     dur: 1000; easing: linear; loop: false; delay:680000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.4977071319479365 -1 -2.724084439847502"
#     animation="property: position; to:0.4977071319479365 0.3 -2.724084439847502
#     dur: 1000; easing: linear; loop: false; delay:632000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.1139607681736379 -1 -0.5880051651984104"
#     animation="property: position; to:-1.1139607681736379 0.3 -0.5880051651984104
#     dur: 1000; easing: linear; loop: false; delay:709000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.007865139205659899 -1 -2.545009461151494"
#     animation="property: position; to:-0.007865139205659899 0.3 -2.545009461151494
#     dur: 1000; easing: linear; loop: false; delay:727000"
#         animation__2="property: position; to:-0.007865139205659899 -1 -2.545009461151494
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.11675094125057517 -1 -3.17032555869082"
#     animation="property: position; to:0.11675094125057517 0.3 -3.17032555869082
#     dur: 1000; easing: linear; loop: false; delay:727000"
#         animation__2="property: position; to:0.11675094125057517 -1 -3.17032555869082
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.2988420049934575 -1 -1.9458522008808359"
#     animation="property: position; to:-1.2988420049934575 0.3 -1.9458522008808359
#     dur: 1000; easing: linear; loop: false; delay:698000"
#         animation__2="property: position; to:-1.2988420049934575 -1 -1.9458522008808359
#         dur: 1000; easing: linear; loop: false; delay:788000" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0277263889486676 -1 -3.249764066253192"
#     animation="property: position; to:1.0277263889486676 0.3 -3.249764066253192
#     dur: 1000; easing: linear; loop: false; delay:699000"
#         animation__2="property: position; to:1.0277263889486676 -1 -3.249764066253192
#         dur: 1000; easing: linear; loop: false; delay:709000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#health_insitution"
#     position="-0.8792486423141781 -1 -2.118019104365885"
#     animation="property: position; to:-0.8792486423141781 0.3 -2.118019104365885
#     dur: 1000; easing: linear; loop: false; delay:577000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.4548623619651153 -1 -2.7115129002522735"
#     animation="property: position; to:0.4548623619651153 0.3 -2.7115129002522735
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:0.4548623619651153 -1 -2.7115129002522735
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.2971467043482334 -1 -2.8135642601719155"
#     animation="property: position; to:-0.2971467043482334 0.3 -2.8135642601719155
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-0.2971467043482334 -1 -2.8135642601719155
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.1947209641431982 -1 -2.70698979215922"
#     animation="property: position; to:-1.1947209641431982 0.3 -2.70698979215922
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-1.1947209641431982 -1 -2.70698979215922
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.8034666855630348 -1 -2.33412690615296"
#     animation="property: position; to:-0.8034666855630348 0.3 -2.33412690615296
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-0.8034666855630348 -1 -2.33412690615296
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.7558693020475402 -1 -2.332430766797188"
#     animation="property: position; to:-0.7558693020475402 0.3 -2.332430766797188
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-0.7558693020475402 -1 -2.332430766797188
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.3898770291068103 -1 -0.8936489627831179"
#     animation="property: position; to:-0.3898770291068103 0.3 -0.8936489627831179
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-0.3898770291068103 -1 -0.8936489627831179
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.7735651546466216 -1 -3.256549065294166"
#     animation="property: position; to:0.7735651546466216 0.3 -3.256549065294166
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:0.7735651546466216 -1 -3.256549065294166
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.010329584271585146 -1 -2.5444440640549146"
#     animation="property: position; to:-0.010329584271585146 0.3 -2.5444440640549146
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-0.010329584271585146 -1 -2.5444440640549146
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.1078440441089696 -1 -1.70178024852612"
#     animation="property: position; to:-1.1078440441089696 0.3 -1.70178024852612
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:-1.1078440441089696 -1 -1.70178024852612
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="-0.6432680401719153 -1 -2.081976467938148"
#     animation="property: position; to:-0.6432680401719153 0.3 -2.081976467938148
#     dur: 1000; easing: linear; loop: false; delay:566000"
#         animation__2="property: position; to:-0.6432680401719153 -1 -2.081976467938148
#         dur: 1000; easing: linear; loop: false; delay:639000" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.4486788333208096 -1 -2.908398129402485"
#     animation="property: position; to:-0.4486788333208096 0.3 -2.908398129402485
#     dur: 1000; easing: linear; loop: false; delay:768000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="0.5181716393147326 -1 -3.050179153429781"
#     animation="property: position; to:0.5181716393147326 0.3 -3.050179153429781
#     dur: 1000; easing: linear; loop: false; delay:-9000"
#         animation__2="property: position; to:0.5181716393147326 -1 -3.050179153429781
#         dur: 1000; easing: linear; loop: false; delay:639000" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="1.2623248699972465 -1 -2.8870641169851297"
#     animation="property: position; to:1.2623248699972465 0.3 -2.8870641169851297
#     dur: 1000; easing: linear; loop: false; delay:731000"
#         animation__2="property: position; to:1.2623248699972465 -1 -2.8870641169851297
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#park"
#     position="0.9827117891784838 -1 -3.327219947688718"
#     animation="property: position; to:0.9827117891784838 0.3 -3.327219947688718
#     dur: 1000; easing: linear; loop: false; delay:654000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.6392720555670166 -1 -3.107566599635902"
#     animation="property: position; to:-1.6392720555670166 0.3 -3.107566599635902
#     dur: 1000; easing: linear; loop: false; delay:727000"
#         animation__2="property: position; to:-1.6392720555670166 -1 -3.107566599635902
#         dur: 1000; easing: linear; loop: false; delay:734000" scale="0"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="0.5565268702137474 -1 -1.395086299151444"
#     animation="property: position; to:0.5565268702137474 0.3 -1.395086299151444
#     dur: 1000; easing: linear; loop: false; delay:217000"
#         animation__2="property: position; to:0.5565268702137474 -1 -1.395086299151444
#         dur: 1000; easing: linear; loop: false; delay:639000" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.6637606967130523 -1 -1.4131354628971167"
#     animation="property: position; to:-0.6637606967130523 0.3 -1.4131354628971167
#     dur: 1000; easing: linear; loop: false; delay:802000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#park"
#     position="0.9965766176776925 -1 -2.62865700182374"
#     animation="property: position; to:0.9965766176776925 0.3 -2.62865700182374
#     dur: 1000; easing: linear; loop: false; delay:781000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="-0.024500988933323198 -1 -2.4576596895203693"
#     animation="property: position; to:-0.024500988933323198 0.3 -2.4576596895203693
#     dur: 1000; easing: linear; loop: false; delay:329000"
#         animation__2="property: position; to:-0.024500988933323198 -1 -2.4576596895203693
#         dur: 1000; easing: linear; loop: false; delay:639000" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.5195984981830406 -1 -2.2622148418631696"
#     animation="property: position; to:-0.5195984981830406 0.3 -2.2622148418631696
#     dur: 1000; easing: linear; loop: false; delay:693000"
#         animation__2="property: position; to:-0.5195984981830406 -1 -2.2622148418631696
#         dur: 1000; easing: linear; loop: false; delay:717000" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="-0.2583293413301362 -1 -3.1431866244729463"
#     animation="property: position; to:-0.2583293413301362 0.3 -3.1431866244729463
#     dur: 1000; easing: linear; loop: false; delay:104000"
#         animation__2="property: position; to:-0.2583293413301362 -1 -3.1431866244729463
#         dur: 1000; easing: linear; loop: false; delay:639000" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.0021483762136995654 -1 -2.082768009568099"
#     animation="property: position; to:0.0021483762136995654 0.3 -2.082768009568099
#     dur: 1000; easing: linear; loop: false; delay:676000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.7723591048245908 -1 -2.765829985441087"
#     animation="property: position; to:0.7723591048245908 0.3 -2.765829985441087
#     dur: 1000; easing: linear; loop: false; delay:798000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.6568050040657909 -1 -2.7748354133073008"
#     animation="property: position; to:0.6568050040657909 0.3 -2.7748354133073008
#     dur: 1000; easing: linear; loop: false; delay:655000"
#         animation__2="property: position; to:0.6568050040657909 -1 -2.7748354133073008
#         dur: 1000; easing: linear; loop: false; delay:673000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="-1.2353867462517882 -1 -2.381334961277389"
#     animation="property: position; to:-1.2353867462517882 0.3 -2.381334961277389
#     dur: 1000; easing: linear; loop: false; delay:666000"
#         animation__2="property: position; to:-1.2353867462517882 -1 -2.381334961277389
#         dur: 1000; easing: linear; loop: false; delay:745000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="-0.031124555493715844 -1 -1.8100433146391879"
#     animation="property: position; to:-0.031124555493715844 0.3 -1.8100433146391879
#     dur: 1000; easing: linear; loop: false; delay:653000"
#         animation__2="property: position; to:-0.031124555493715844 -1 -1.8100433146391879
#         dur: 1000; easing: linear; loop: false; delay:680000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="-1.1573775836374807 -1 -3.273569530381792"
#     animation="property: position; to:-1.1573775836374807 0.3 -3.273569530381792
#     dur: 1000; easing: linear; loop: false; delay:676000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.1527957548594714 -1 -2.0828244044569146"
#     animation="property: position; to:0.1527957548594714 0.3 -2.0828244044569146
#     dur: 1000; easing: linear; loop: false; delay:672000"
#         animation__2="property: position; to:0.1527957548594714 -1 -2.0828244044569146
#         dur: 1000; easing: linear; loop: false; delay:746000" scale="0.00007 0.00007 0.00007"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.5853575007765357 -1 -3.6459103205907013"
#     animation="property: position; to:-1.5853575007765357 0.3 -3.6459103205907013
#     dur: 1000; easing: linear; loop: false; delay:714000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.5786541219974424 -1 -3.2634788297691557"
#     animation="property: position; to:-1.5786541219974424 0.3 -3.2634788297691557
#     dur: 1000; easing: linear; loop: false; delay:714000" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="1.700000000000091 -1 -2.0655371346947504"
#     animation="property: position; to:1.700000000000091 0.3 -2.0655371346947504
#     dur: 1000; easing: linear; loop: false; delay:702000" scale="0.02 0.02 0.02"></a-entity>
