# %%
# %%capture

#standard libraries
import os
import pandas as pd
import numpy as np
import regex as re

#for visuals
import matplotlib.pyplot as plt

#for coordinate conversion
# !pip install utm
import utm

#for scaling the coordinates
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler(feature_range=(0,3.4))

# %%
df = pd.read_csv('../data/district_data.csv', sep= ";")

plt.scatter(x=df["LONG"], y=df["LAT"])

# %%
import pyproj
from shapely.geometry import Point

# Create a projection 
# in Web Mercator the same that leaflet uses which was used for the 2D application
project = pyproj.Transformer.from_crs("EPSG:4326", "EPSG:3857", always_xy=True)

row_counter = 0
x_coordinates = []
y_coordinates = []
for i in df.iterrows():
    
    x_y = project.transform(df.iloc[row_counter]["LONG"], df.iloc[row_counter]["LAT"])
    x = x_y[0]
    y = x_y[1]
    x_coordinates.append(x)
    y_coordinates.append(y)
    row_counter += 1
    
df["X_coord"] = x_coordinates
df["Y_coord"] = y_coordinates


df[['X_coord', 'Y_coord']] = scaler.fit_transform(df[['X_coord', 'Y_coord']])
df["Y_coord"]  =  df["Y_coord"]+0.5
df["X_coord"]  =  df["X_coord"]-1.7

plt.scatter(df["X_coord"], df["Y_coord"])

# %%
df["scale"] = 0

df.loc[df["TYPE"] == "church", "scale"] = "0.018 0.036 0.018"
df.loc[df["TYPE"] == "farm", "scale"] = "0.014 0.0145 0.014"
df.loc[df["TYPE"] == "settlement", "scale"] = "0.2 0.2 0.2"
df.loc[df["TYPE"] == "building", "scale"] = "0.003 0.003 0.003"
df.loc[df["TYPE"] == "cinema", "scale"] = "0.02 0.02 0.02"
df.loc[df["TYPE"] == "coffee_house", "scale"] = "0.002 0.002 0.002"
df.loc[df["TYPE"] == "health_institution", "scale"] = "0.05 0.05 0.05"
df.loc[df["TYPE"] == "ns_institution", "scale"] = "0.1 0.1 0.1"
df.loc[df["TYPE"] == "park", "scale"] = "0.005 0.005 0.005"
df.loc[df["TYPE"] == "school", "scale"] = "0.006 0.006 0.006"
df.loc[df["TYPE"] == "statue", "scale"] = "0.012 0.012 0.012"
df.loc[df["TYPE"] == "theatre", "scale"] = "0.04 0.04 0.04"

df["delay_appearance"] = (df["DATUM_VON"] -1311) /1000
df["delay_vanishing"] = (df["DATUM_BIS"] -1311) /1000

# %%
df[df["TYPE"] == "school"]
# Out:
#                         SEITENNAME    TYPE  DATUM_VON  DATUM_BIS  \
# 64     Savoyische Adelige Akademie  school       1746          0
# 137  VS/HS Lerchenfelder Straße 61  school       1865       1935
# 138       WMS Neustiftgasse 98-102  school       1891          0
# 167              MS Neubaugasse 42  school       1887          0
# 168            PTS Burggasse 14-16  school       2009          0
# 169                VS Burggasse 20  school       1866       1884
# 170               VS Kandlgasse 30  school       1877       1956
# 171              VS Neubaugasse 25  school       1864       1891
# 172        VS Neustiftgasse 98-102  school       1887          0
# 173              VS Zollergasse 41  school       1883       1957
#
#                             BENANNT_NACH                     STREET  DISTRICT  \
# 64   Maria Theresia von Savoyen-Carignan     Stiftgasse 2A(KASERNE)         7
# 137                                  NaN  Lerchenfelder Straße 61/1         7
# 138                                  NaN   Neustiftgasse 98(SCHULE)         7
# 167                                  NaN     Neubaugasse 42(SCHULE)         7
# 168                                  NaN            Burggasse 14-16         7
# 169                                  NaN             Burggasse 20/2         7
# 170                                  NaN              Kandlgasse 30         7
# 171                                  NaN           Neubaugasse 25/1         7
# 172                                  NaN   Neustiftgasse 98(SCHULE)         7
# 173                                  NaN     Zollergasse 41(SCHULE)         7
#
#                                              SHAPE  \
# 64   POINT (16.355101870428353 48.201937682942884)
# 137   POINT (16.347281015940023 48.20667004095614)
# 138   POINT (16.341664446696182 48.20601124790739)
# 167    POINT (16.34919202228352 48.20179884134287)
# 168    POINT (16.354192185866353 48.2042151845777)
# 169   POINT (16.353442015315625 48.20424704066904)
# 170   POINT (16.341158015716267 48.20285504098191)
# 171   POINT (16.348976016331857 48.20083404130371)
# 172   POINT (16.341664446696182 48.20601124790739)
# 173    POINT (16.35017001636822 48.20179904084544)
#
#                                               WEBLINK1       LONG        LAT  \
# 64   https://www.geschichtewiki.wien.gv.at/?curid=2627  16.355102  48.201938
# 137  https://www.geschichtewiki.wien.gv.at/?curid=7...  16.347281  48.206670
# 138  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.341664  48.206011
# 167  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.349192  48.201799
# 168  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.354192  48.204215
# 169  https://www.geschichtewiki.wien.gv.at/?curid=7...  16.353442  48.204247
# 170  https://www.geschichtewiki.wien.gv.at/?curid=7...  16.341158  48.202855
# 171  https://www.geschichtewiki.wien.gv.at/?curid=7...  16.348976  48.200834
# 172  https://www.geschichtewiki.wien.gv.at/?curid=6...  16.341664  48.206011
# 173  https://www.geschichtewiki.wien.gv.at/?curid=7...  16.350170  48.201799
#
#       X_coord   Y_coord              scale  delay_appearance  delay_vanishing
# 64   0.912484  2.122015  0.006 0.006 0.006             0.435           -1.311
# 137 -0.292218  3.459812  0.006 0.006 0.006             0.554            0.624
# 138 -1.157378  3.273570  0.006 0.006 0.006             0.580           -1.311
# 167  0.002148  2.082768  0.006 0.006 0.006             0.576           -1.311
# 168  0.772359  2.765830  0.006 0.006 0.006             0.698           -1.311
# 169  0.656805  2.774835  0.006 0.006 0.006             0.555            0.573
# 170 -1.235387  2.381335  0.006 0.006 0.006             0.566            0.645
# 171 -0.031125  1.810043  0.006 0.006 0.006             0.553            0.580
# 172 -1.157378  3.273570  0.006 0.006 0.006             0.576           -1.311
# 173  0.152796  2.082824  0.006 0.006 0.006             0.572            0.646

# %%
for i, n in enumerate(df.iterrows()):
    code='''<a-entity gltf-model="#{0}"   
    position="{1} -1 {2}" 
    animation="property: position; to:{1} 0.23 {2}  
    dur: 1000; easing: linear; loop: false; delay:{3}" '''.format(str(df.iloc[i]["TYPE"]), 
                                                                  str(df.iloc[i]["X_coord"]), 
                                                                  str(-df.iloc[i]["Y_coord"]), 
                                                                  str(df.iloc[i]["delay_appearance"]))
    
    if df.iloc[i]["delay_vanishing"] > 0:
        code+='''
        animation__2="property: position; to:{0} -1 {1}
        dur: 1000; easing: linear; loop: false; delay:{2}" '''.format(str(df.iloc[i]["X_coord"]),
                                                                   str(-df.iloc[i]["Y_coord"]),
                                                                   str(df.iloc[i]["delay_vanishing"]))
    else:
        pass
    
    if df.iloc[i]["TYPE"] =="church" or df.iloc[i]["TYPE"] =="theatre":
        code+=''' rotation="0 -40 0" '''
    else:
        pass
            
    
    code+='scale="{0}"></a-entity>'.format(str(df.iloc[i]["scale"]))
    print(code)
# Out:
# <a-entity gltf-model="#park"
#     position="-0.5335935804843757 -1 -1.7388099749714456"
#     animation="property: position; to:-0.5335935804843757 0.23 -1.7388099749714456
#     dur: 1000; easing: linear; loop: false; delay:0.696" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#statue"
#     position="0.522505476819606 -1 -2.920090252226146"
#     animation="property: position; to:0.522505476819606 0.23 -2.920090252226146
#     dur: 1000; easing: linear; loop: false; delay:0.439" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#health_institution"
#     position="0.5926097250742715 -1 -2.7869558368456637"
#     animation="property: position; to:0.5926097250742715 0.23 -2.7869558368456637
#     dur: 1000; easing: linear; loop: false; delay:0.402" scale="0.05 0.05 0.05"></a-entity>
# <a-entity gltf-model="#health_institution"
#     position="0.793053964682531 -1 -2.2967512680716027"
#     animation="property: position; to:0.793053964682531 0.23 -2.2967512680716027
#     dur: 1000; easing: linear; loop: false; delay:0.472" scale="0.05 0.05 0.05"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.23 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:0.438"
#         animation__2="property: position; to:0.034188476826602754 -1 -1.960508170472167
#         dur: 1000; easing: linear; loop: false; delay:0.664" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7889071580510063 -1 -3.145167100974504"
#     animation="property: position; to:0.7889071580510063 0.23 -3.145167100974504
#     dur: 1000; easing: linear; loop: false; delay:0.39" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.773365142685907 -1 -3.2574938744073734"
#     animation="property: position; to:0.773365142685907 0.23 -3.2574938744073734
#     dur: 1000; easing: linear; loop: false; delay:0.5" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.327482584469908 -1 -2.631229073753275"
#     animation="property: position; to:1.327482584469908 0.23 -2.631229073753275
#     dur: 1000; easing: linear; loop: false; delay:0.651" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7723591048245908 -1 -2.765829985441087"
#     animation="property: position; to:0.7723591048245908 0.23 -2.765829985441087
#     dur: 1000; easing: linear; loop: false; delay:0.612"
#         animation__2="property: position; to:0.7723591048245908 -1 -2.765829985441087
#         dur: 1000; easing: linear; loop: false; delay:0.696" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.33060038568719397 -1 -2.2393187284724263"
#     animation="property: position; to:0.33060038568719397 0.23 -2.2393187284724263
#     dur: 1000; easing: linear; loop: false; delay:0.627"
#         animation__2="property: position; to:0.33060038568719397 -1 -2.2393187284724263
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5316938722810847 -1 -2.574248753955544"
#     animation="property: position; to:1.5316938722810847 0.23 -2.574248753955544
#     dur: 1000; easing: linear; loop: false; delay:0.69" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.20440577134722848 -1 -3.173233387484288"
#     animation="property: position; to:0.20440577134722848 0.23 -3.173233387484288
#     dur: 1000; easing: linear; loop: false; delay:0.592"
#         animation__2="property: position; to:0.20440577134722848 -1 -3.173233387484288
#         dur: 1000; easing: linear; loop: false; delay:0.621" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.2587915687801796 -1 -1.2223795748886914"
#     animation="property: position; to:-0.2587915687801796 0.23 -1.2223795748886914
#     dur: 1000; easing: linear; loop: false; delay:0.686" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#church"
#     position="0.5226300878328403 -1 -2.9216410405897477"
#     animation="property: position; to:0.5226300878328403 0.23 -2.9216410405897477
#     dur: 1000; easing: linear; loop: false; delay:-0.1"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#church"
#     position="0.7951621770833299 -1 -3.126758547488862"
#     animation="property: position; to:0.7951621770833299 0.23 -3.126758547488862
#     dur: 1000; easing: linear; loop: false; delay:0.526"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#statue"
#     position="-1.630337950055673 -1 -1.993215932561725"
#     animation="property: position; to:-1.630337950055673 0.23 -1.993215932561725
#     dur: 1000; easing: linear; loop: false; delay:0.59" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.22787751781534094 -1 -0.9483957975789963"
#     animation="property: position; to:-0.22787751781534094 0.23 -0.9483957975789963
#     dur: 1000; easing: linear; loop: false; delay:0.644" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.801312300420068 -1 -2.4594264942916197"
#     animation="property: position; to:0.801312300420068 0.23 -2.4594264942916197
#     dur: 1000; easing: linear; loop: false; delay:0.655" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.5983668810243217 -1 -1.8420095854235115"
#     animation="property: position; to:0.5983668810243217 0.23 -1.8420095854235115
#     dur: 1000; easing: linear; loop: false; delay:0.535" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.2090191980143572 -1 -0.6864117174936837"
#     animation="property: position; to:-1.2090191980143572 0.23 -0.6864117174936837
#     dur: 1000; easing: linear; loop: false; delay:0.314" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5274227794359831 -1 -2.3134910681910696"
#     animation="property: position; to:1.5274227794359831 0.23 -2.3134910681910696
#     dur: 1000; easing: linear; loop: false; delay:0.69" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.23 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:0.68" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.004354561949003299 -1 -2.0027652448643494"
#     animation="property: position; to:0.004354561949003299 0.23 -2.0027652448643494
#     dur: 1000; easing: linear; loop: false; delay:0.491"
#         animation__2="property: position; to:0.004354561949003299 -1 -2.0027652448643494
#         dur: 1000; easing: linear; loop: false; delay:0.6" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7951621770833299 -1 -3.126758547488862"
#     animation="property: position; to:0.7951621770833299 0.23 -3.126758547488862
#     dur: 1000; easing: linear; loop: false; delay:0.214" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="0.8727650368094146 -1 -3.450200091874649"
#     animation="property: position; to:0.8727650368094146 0.23 -3.450200091874649
#     dur: 1000; easing: linear; loop: false; delay:0.671" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0771782721461023 -1 -3.0649185276142816"
#     animation="property: position; to:1.0771782721461023 0.23 -3.0649185276142816
#     dur: 1000; easing: linear; loop: false; delay:0.495"
#         animation__2="property: position; to:1.0771782721461023 -1 -3.0649185276142816
#         dur: 1000; easing: linear; loop: false; delay:0.554" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="1.182687719873502 -1 -3.179937387443715"
#     animation="property: position; to:1.182687719873502 0.23 -3.179937387443715
#     dur: 1000; easing: linear; loop: false; delay:0.587" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.23 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:0.656" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#church"
#     position="-1.3506064976701964 -1 -0.7311237930207426"
#     animation="property: position; to:-1.3506064976701964 0.23 -0.7311237930207426
#     dur: 1000; easing: linear; loop: false; delay:0.549"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.5895969164937014 -1 -1.6486238450888777"
#     animation="property: position; to:-0.5895969164937014 0.23 -1.6486238450888777
#     dur: 1000; easing: linear; loop: false; delay:0.661"
#         animation__2="property: position; to:-0.5895969164937014 -1 -1.6486238450888777
#         dur: 1000; easing: linear; loop: false; delay:0.678" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5316938722810847 -1 -2.574248753955544"
#     animation="property: position; to:1.5316938722810847 0.23 -2.574248753955544
#     dur: 1000; easing: linear; loop: false; delay:0.693" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="1.6571220611388526 -1 -2.7346934541346855"
#     animation="property: position; to:1.6571220611388526 0.23 -2.7346934541346855
#     dur: 1000; easing: linear; loop: false; delay:0.581" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#statue"
#     position="-1.6309540331983043 -1 -1.9926505785570043"
#     animation="property: position; to:-1.6309540331983043 0.23 -1.9926505785570043
#     dur: 1000; easing: linear; loop: false; delay:0.59" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#church"
#     position="1.042821979774817 -1 -1.751530267760245"
#     animation="property: position; to:1.042821979774817 0.23 -1.751530267760245
#     dur: 1000; easing: linear; loop: false; delay:0.428"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.8985159330115493 -1 -1.363442594787557"
#     animation="property: position; to:-0.8985159330115493 0.23 -1.363442594787557
#     dur: 1000; easing: linear; loop: false; delay:0.595" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#church"
#     position="-0.6871686152619076 -1 -2.026289039229596"
#     animation="property: position; to:-0.6871686152619076 0.23 -2.026289039229596
#     dur: 1000; easing: linear; loop: false; delay:0.473"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.563504241143346 -1 -1.9367417133580602"
#     animation="property: position; to:-1.563504241143346 0.23 -1.9367417133580602
#     dur: 1000; easing: linear; loop: false; delay:0.619" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7365133229662206 -1 -3.1230635635311046"
#     animation="property: position; to:0.7365133229662206 0.23 -3.1230635635311046
#     dur: 1000; easing: linear; loop: false; delay:0.589" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.652480102499976 -1 -1.2792946541267156"
#     animation="property: position; to:-0.652480102499976 0.23 -1.2792946541267156
#     dur: 1000; easing: linear; loop: false; delay:0.528"
#         animation__2="property: position; to:-0.652480102499976 -1 -1.2792946541267156
#         dur: 1000; easing: linear; loop: false; delay:0.565" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.652480102499976 -1 -1.2792946541267156"
#     animation="property: position; to:-0.652480102499976 0.23 -1.2792946541267156
#     dur: 1000; easing: linear; loop: false; delay:0.496"
#         animation__2="property: position; to:-0.652480102499976 -1 -1.2792946541267156
#         dur: 1000; easing: linear; loop: false; delay:0.565" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.32704071675352675 -1 -0.8687853252431523"
#     animation="property: position; to:-0.32704071675352675 0.23 -0.8687853252431523
#     dur: 1000; easing: linear; loop: false; delay:0.59" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.9101162396734253 -1 -3.052993770694229"
#     animation="property: position; to:-0.9101162396734253 0.23 -3.052993770694229
#     dur: 1000; easing: linear; loop: false; delay:0.601" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.03446277810480747 -1 -1.8151114938991668"
#     animation="property: position; to:-0.03446277810480747 0.23 -1.8151114938991668
#     dur: 1000; easing: linear; loop: false; delay:0.6" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.6228303374316966 -1 -1.9821577774764592"
#     animation="property: position; to:1.6228303374316966 0.23 -1.9821577774764592
#     dur: 1000; easing: linear; loop: false; delay:0.587" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#coffee_house"
#     position="-1.3856465994114842 -1 -0.5"
#     animation="property: position; to:-1.3856465994114842 0.23 -0.5
#     dur: 1000; easing: linear; loop: false; delay:0.579" scale="0.002 0.002 0.002"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.24011645174623486 -1 -2.712072034826633"
#     animation="property: position; to:0.24011645174623486 0.23 -2.712072034826633
#     dur: 1000; easing: linear; loop: false; delay:0.563" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.23 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:0.375"
#         animation__2="property: position; to:0.034188476826602754 -1 -1.960508170472167
#         dur: 1000; easing: linear; loop: false; delay:0.443" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.3258082231092885 -1 -2.240747680698405"
#     animation="property: position; to:-1.3258082231092885 0.23 -2.240747680698405
#     dur: 1000; easing: linear; loop: false; delay:0.51" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.5964025854243118 -1 -2.9547859666399745"
#     animation="property: position; to:-1.5964025854243118 0.23 -2.9547859666399745
#     dur: 1000; easing: linear; loop: false; delay:0.583" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.5780884297308149 -1 -2.8189419902810187"
#     animation="property: position; to:0.5780884297308149 0.23 -2.8189419902810187
#     dur: 1000; easing: linear; loop: false; delay:0.022"
#         animation__2="property: position; to:0.5780884297308149 -1 -2.8189419902810187
#         dur: 1000; easing: linear; loop: false; delay:0.218" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.3088682391300608 -1 -1.583421683702909"
#     animation="property: position; to:-1.3088682391300608 0.23 -1.583421683702909
#     dur: 1000; easing: linear; loop: false; delay:0.579" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.5316938722810847 -1 -2.574248753955544"
#     animation="property: position; to:1.5316938722810847 0.23 -2.574248753955544
#     dur: 1000; easing: linear; loop: false; delay:0.408" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.3446170751629325 -1 -2.034872139340223"
#     animation="property: position; to:0.3446170751629325 0.23 -2.034872139340223
#     dur: 1000; easing: linear; loop: false; delay:0.587" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.7257258807346261 -1 -1.316494827349743"
#     animation="property: position; to:-0.7257258807346261 0.23 -1.316494827349743
#     dur: 1000; easing: linear; loop: false; delay:0.651" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.6669570442156327 -1 -1.5798312642727979"
#     animation="property: position; to:-1.6669570442156327 0.23 -1.5798312642727979
#     dur: 1000; easing: linear; loop: false; delay:0.689" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.6649643795992233 -1 -1.7230535996604885"
#     animation="property: position; to:-1.6649643795992233 0.23 -1.7230535996604885
#     dur: 1000; easing: linear; loop: false; delay:0.562" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.09985499903286832 -1 -2.8060070770516177"
#     animation="property: position; to:-0.09985499903286832 0.23 -2.8060070770516177
#     dur: 1000; easing: linear; loop: false; delay:0.59" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.4556659254523765 -1 -2.1028595911266166"
#     animation="property: position; to:-0.4556659254523765 0.23 -2.1028595911266166
#     dur: 1000; easing: linear; loop: false; delay:0.483"
#         animation__2="property: position; to:-0.4556659254523765 -1 -2.1028595911266166
#         dur: 1000; easing: linear; loop: false; delay:0.536" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#health_institution"
#     position="-1.7 -1 -3.8931960230147524"
#     animation="property: position; to:-1.7 0.23 -3.8931960230147524
#     dur: 1000; easing: linear; loop: false; delay:0.563"
#         animation__2="property: position; to:-1.7 -1 -3.8931960230147524
#         dur: 1000; easing: linear; loop: false; delay:0.598" scale="0.05 0.05 0.05"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.32988853991964784 -1 -3.119214917966019"
#     animation="property: position; to:-0.32988853991964784 0.23 -3.119214917966019
#     dur: 1000; easing: linear; loop: false; delay:0.687" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.38083676618980467 -1 -3.151785286321683"
#     animation="property: position; to:0.38083676618980467 0.23 -3.151785286321683
#     dur: 1000; easing: linear; loop: false; delay:0.318"
#         animation__2="property: position; to:0.38083676618980467 -1 -3.151785286321683
#         dur: 1000; easing: linear; loop: false; delay:0.477" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#theatre"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.23 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:0.621"  rotation="0 -40 0" scale="0.04 0.04 0.04"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.7236451632031276 -1 -2.115762496212483"
#     animation="property: position; to:-0.7236451632031276 0.23 -2.115762496212483
#     dur: 1000; easing: linear; loop: false; delay:0.601" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.5746565384359201 -1 -2.864882557796591"
#     animation="property: position; to:0.5746565384359201 0.23 -2.864882557796591
#     dur: 1000; easing: linear; loop: false; delay:0.439" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.9124842822705432 -1 -2.122015459166505"
#     animation="property: position; to:0.9124842822705432 0.23 -2.122015459166505
#     dur: 1000; easing: linear; loop: false; delay:0.435" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#health_institution"
#     position="-1.2672724427595312 -1 -0.9473535074139363"
#     animation="property: position; to:-1.2672724427595312 0.23 -0.9473535074139363
#     dur: 1000; easing: linear; loop: false; delay:0.57"
#         animation__2="property: position; to:-1.2672724427595312 -1 -0.9473535074139363
#         dur: 1000; easing: linear; loop: false; delay:0.706" scale="0.05 0.05 0.05"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8790314071973626 -1 -2.7114951591593126"
#     animation="property: position; to:0.8790314071973626 0.23 -2.7114951591593126
#     dur: 1000; easing: linear; loop: false; delay:0.429" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0322810520986423 -1 -3.215949434070353"
#     animation="property: position; to:1.0322810520986423 0.23 -3.215949434070353
#     dur: 1000; easing: linear; loop: false; delay:0.401" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.12514151282466623 -1 -3.0936517907448433"
#     animation="property: position; to:-0.12514151282466623 0.23 -3.0936517907448433
#     dur: 1000; easing: linear; loop: false; delay:0.6" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.4527148630580087 -1 -2.5014759012028662"
#     animation="property: position; to:1.4527148630580087 0.23 -2.5014759012028662
#     dur: 1000; easing: linear; loop: false; delay:0.408" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8259057015396138 -1 -3.073029479402976"
#     animation="property: position; to:0.8259057015396138 0.23 -3.073029479402976
#     dur: 1000; easing: linear; loop: false; delay:0.401" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.0967535291881176 -1 -2.058732960247653"
#     animation="property: position; to:-1.0967535291881176 0.23 -2.058732960247653
#     dur: 1000; easing: linear; loop: false; delay:0.597" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.1139607681736379 -1 -0.5880051651984104"
#     animation="property: position; to:-1.1139607681736379 0.23 -0.5880051651984104
#     dur: 1000; easing: linear; loop: false; delay:0.6"
#         animation__2="property: position; to:-1.1139607681736379 -1 -0.5880051651984104
#         dur: 1000; easing: linear; loop: false; delay:0.685" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.3851237640363252 -1 -3.134674084656581"
#     animation="property: position; to:0.3851237640363252 0.23 -3.134674084656581
#     dur: 1000; easing: linear; loop: false; delay:0.318"
#         animation__2="property: position; to:0.3851237640363252 -1 -3.134674084656581
#         dur: 1000; easing: linear; loop: false; delay:0.477" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.4553072856454492 -1 -2.2341015704369056"
#     animation="property: position; to:0.4553072856454492 0.23 -2.2341015704369056
#     dur: 1000; easing: linear; loop: false; delay:0.588" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.985378157708783 -1 -1.886308520770399"
#     animation="property: position; to:0.985378157708783 0.23 -1.886308520770399
#     dur: 1000; easing: linear; loop: false; delay:0.428" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#theatre"
#     position="0.034188476826602754 -1 -1.960508170472167"
#     animation="property: position; to:0.034188476826602754 0.23 -1.960508170472167
#     dur: 1000; easing: linear; loop: false; delay:0.601"  rotation="0 -40 0" scale="0.04 0.04 0.04"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.010635802991328047 -1 -2.5449215647058736"
#     animation="property: position; to:-0.010635802991328047 0.23 -2.5449215647058736
#     dur: 1000; easing: linear; loop: false; delay:0.593" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#farm"
#     position="0.42069856467678624 -1 -3.3353610051017313"
#     animation="property: position; to:0.42069856467678624 0.23 -3.3353610051017313
#     dur: 1000; easing: linear; loop: false; delay:0.065"
#         animation__2="property: position; to:0.42069856467678624 -1 -3.3353610051017313
#         dur: 1000; easing: linear; loop: false; delay:0.459" scale="0.014 0.0145 0.014"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9796765863291512 -1 -2.3749704562997067"
#     animation="property: position; to:0.9796765863291512 0.23 -2.3749704562997067
#     dur: 1000; easing: linear; loop: false; delay:0.551" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#church"
#     position="-0.935633169931134 -1 -3.530305719035823"
#     animation="property: position; to:-0.935633169931134 0.23 -3.530305719035823
#     dur: 1000; easing: linear; loop: false; delay:0.537"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0049360156083822 -1 -2.367793498618994"
#     animation="property: position; to:1.0049360156083822 0.23 -2.367793498618994
#     dur: 1000; easing: linear; loop: false; delay:0.585" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9627432482391669 -1 -2.461920369834843"
#     animation="property: position; to:0.9627432482391669 0.23 -2.461920369834843
#     dur: 1000; easing: linear; loop: false; delay:0.581" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9911224251443855 -1 -2.508816169896818"
#     animation="property: position; to:0.9911224251443855 0.23 -2.508816169896818
#     dur: 1000; easing: linear; loop: false; delay:0.412" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="1.2207349088451338 -1 -2.9746993255339476"
#     animation="property: position; to:1.2207349088451338 0.23 -2.9746993255339476
#     dur: 1000; easing: linear; loop: false; delay:0.641" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.6719735025242699 -1 -2.191944855690963"
#     animation="property: position; to:0.6719735025242699 0.23 -2.191944855690963
#     dur: 1000; easing: linear; loop: false; delay:0.389"
#         animation__2="property: position; to:0.6719735025242699 -1 -2.191944855690963
#         dur: 1000; easing: linear; loop: false; delay:0.681" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="-1.6363452532775227 -1 -1.1641516954441613"
#     animation="property: position; to:-1.6363452532775227 0.23 -1.1641516954441613
#     dur: 1000; easing: linear; loop: false; delay:0.598" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0911675894974906 -1 -2.3895277090941818"
#     animation="property: position; to:1.0911675894974906 0.23 -2.3895277090941818
#     dur: 1000; easing: linear; loop: false; delay:0.525" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.3856465994114842 -1 -0.5"
#     animation="property: position; to:-1.3856465994114842 0.23 -0.5
#     dur: 1000; easing: linear; loop: false; delay:0.588" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.2370667771958324 -1 -2.3882916714374005"
#     animation="property: position; to:-1.2370667771958324 0.23 -2.3882916714374005
#     dur: 1000; easing: linear; loop: false; delay:0.647" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.39009036198940517 -1 -0.8944446373770916"
#     animation="property: position; to:-0.39009036198940517 0.23 -0.8944446373770916
#     dur: 1000; easing: linear; loop: false; delay:0.589" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.18545606020443306 -1 -1.8002687453845283"
#     animation="property: position; to:0.18545606020443306 0.23 -1.8002687453845283
#     dur: 1000; easing: linear; loop: false; delay:0.267" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7843439600658713 -1 -2.6936507293012255"
#     animation="property: position; to:0.7843439600658713 0.23 -2.6936507293012255
#     dur: 1000; easing: linear; loop: false; delay:0.579" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.06227441553010071 -1 -1.4323266238079668"
#     animation="property: position; to:0.06227441553010071 0.23 -1.4323266238079668
#     dur: 1000; easing: linear; loop: false; delay:0.509" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.854618568044134 -1 -2.2862084000298637"
#     animation="property: position; to:0.854618568044134 0.23 -2.2862084000298637
#     dur: 1000; easing: linear; loop: false; delay:0.559" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9010954179605506 -1 -2.5775102928128035"
#     animation="property: position; to:0.9010954179605506 0.23 -2.5775102928128035
#     dur: 1000; easing: linear; loop: false; delay:0.409" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8259057015396138 -1 -3.073029479402976"
#     animation="property: position; to:0.8259057015396138 0.23 -3.073029479402976
#     dur: 1000; easing: linear; loop: false; delay:0.401" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.17649444538692483 -1 -2.6989684305499395"
#     animation="property: position; to:0.17649444538692483 0.23 -2.6989684305499395
#     dur: 1000; easing: linear; loop: false; delay:0.377" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#statue"
#     position="0.5161692319778013 -1 -2.7994296406559442"
#     animation="property: position; to:0.5161692319778013 0.23 -2.7994296406559442
#     dur: 1000; easing: linear; loop: false; delay:0.402" scale="0.012 0.012 0.012"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9799814328255707 -1 -2.748531093049678"
#     animation="property: position; to:0.9799814328255707 0.23 -2.748531093049678
#     dur: 1000; easing: linear; loop: false; delay:0.489" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.42488381358070915 -1 -1.351404340357476"
#     animation="property: position; to:0.42488381358070915 0.23 -1.351404340357476
#     dur: 1000; easing: linear; loop: false; delay:0.372"
#         animation__2="property: position; to:0.42488381358070915 -1 -1.351404340357476
#         dur: 1000; easing: linear; loop: false; delay:0.582" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7663359776081962 -1 -1.9368357728562842"
#     animation="property: position; to:0.7663359776081962 0.23 -1.9368357728562842
#     dur: 1000; easing: linear; loop: false; delay:0.385" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9582197103039107 -1 -2.7369195059345657"
#     animation="property: position; to:0.9582197103039107 0.23 -2.7369195059345657
#     dur: 1000; easing: linear; loop: false; delay:0.439" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.13987848378446865 -1 -2.752829894579918"
#     animation="property: position; to:-0.13987848378446865 0.23 -2.752829894579918
#     dur: 1000; easing: linear; loop: false; delay:0.379" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.8934820079000929 -1 -2.6407135518493305"
#     animation="property: position; to:0.8934820079000929 0.23 -2.6407135518493305
#     dur: 1000; easing: linear; loop: false; delay:0.665" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.7439859464746406 -1 -1.5473378591523215"
#     animation="property: position; to:0.7439859464746406 0.23 -1.5473378591523215
#     dur: 1000; easing: linear; loop: false; delay:0.593" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.9389973829700466 -1 -1.6574040254599822"
#     animation="property: position; to:0.9389973829700466 0.23 -1.6574040254599822
#     dur: 1000; easing: linear; loop: false; delay:0.585" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.443221226069727 -1 -1.9371511747485783"
#     animation="property: position; to:1.443221226069727 0.23 -1.9371511747485783
#     dur: 1000; easing: linear; loop: false; delay:0.583" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.181142204146272 -1 -2.4690451952465082"
#     animation="property: position; to:1.181142204146272 0.23 -2.4690451952465082
#     dur: 1000; easing: linear; loop: false; delay:0.579" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.08238854271148743 -1 -1.1010942380544293"
#     animation="property: position; to:0.08238854271148743 0.23 -1.1010942380544293
#     dur: 1000; easing: linear; loop: false; delay:0.607" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.11984265208293432 -1 -0.974112120034988"
#     animation="property: position; to:-0.11984265208293432 0.23 -0.974112120034988
#     dur: 1000; easing: linear; loop: false; delay:0.61" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.32704071675352675 -1 -0.8687853252431523"
#     animation="property: position; to:-0.32704071675352675 0.23 -0.8687853252431523
#     dur: 1000; easing: linear; loop: false; delay:0.608"
#         animation__2="property: position; to:-0.32704071675352675 -1 -0.8687853252431523
#         dur: 1000; easing: linear; loop: false; delay:0.619" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.2553372085173577 -1 -2.123470694561547"
#     animation="property: position; to:-1.2553372085173577 0.23 -2.123470694561547
#     dur: 1000; easing: linear; loop: false; delay:0.61" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.3378879699318531 -1 -2.7585101377535466"
#     animation="property: position; to:-0.3378879699318531 0.23 -2.7585101377535466
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:-0.3378879699318531 -1 -2.7585101377535466
#         dur: 1000; easing: linear; loop: false; delay:0.689" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.4983008393121964 -1 -2.722820510589372"
#     animation="property: position; to:0.4983008393121964 0.23 -2.722820510589372
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:0.4983008393121964 -1 -2.722820510589372
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#health_institution"
#     position="-0.04492711503798996 -1 -2.1229696894915833"
#     animation="property: position; to:-0.04492711503798996 0.23 -2.1229696894915833
#     dur: 1000; easing: linear; loop: false; delay:0.472" scale="0.05 0.05 0.05"></a-entity>
# <a-entity gltf-model="#building"
#     position="-0.90700350034258 -1 -2.5623530251141347"
#     animation="property: position; to:-0.90700350034258 0.23 -2.5623530251141347
#     dur: 1000; easing: linear; loop: false; delay:0.613"
#         animation__2="property: position; to:-0.90700350034258 -1 -2.5623530251141347
#         dur: 1000; easing: linear; loop: false; delay:0.627" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.6719735025242699 -1 -2.191944855690963"
#     animation="property: position; to:0.6719735025242699 0.23 -2.191944855690963
#     dur: 1000; easing: linear; loop: false; delay:0.389"
#         animation__2="property: position; to:0.6719735025242699 -1 -2.191944855690963
#         dur: 1000; easing: linear; loop: false; delay:0.681" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.09410746435360129 -1 -1.1486052951840975"
#     animation="property: position; to:0.09410746435360129 0.23 -1.1486052951840975
#     dur: 1000; easing: linear; loop: false; delay:0.608"
#         animation__2="property: position; to:0.09410746435360129 -1 -1.1486052951840975
#         dur: 1000; easing: linear; loop: false; delay:0.613" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.6064384378771137 -1 -2.749977277519065"
#     animation="property: position; to:-1.6064384378771137 0.23 -2.749977277519065
#     dur: 1000; easing: linear; loop: false; delay:0.602" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="1.6228303374316966 -1 -1.9821577774764592"
#     animation="property: position; to:1.6228303374316966 0.23 -1.9821577774764592
#     dur: 1000; easing: linear; loop: false; delay:0.596"
#         animation__2="property: position; to:1.6228303374316966 -1 -1.9821577774764592
#         dur: 1000; easing: linear; loop: false; delay:0.598" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.1259588721625733 -1 -1.203960322533021"
#     animation="property: position; to:0.1259588721625733 0.23 -1.203960322533021
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:0.1259588721625733 -1 -1.203960322533021
#         dur: 1000; easing: linear; loop: false; delay:0.606" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.4736017757738409 -1 -3.900000000001455"
#     animation="property: position; to:-1.4736017757738409 0.23 -3.900000000001455
#     dur: 1000; easing: linear; loop: false; delay:0.608"
#         animation__2="property: position; to:-1.4736017757738409 -1 -3.900000000001455
#         dur: 1000; easing: linear; loop: false; delay:0.615" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.3424744296478821 -1 -3.0074905166802637"
#     animation="property: position; to:0.3424744296478821 0.23 -3.0074905166802637
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:0.3424744296478821 -1 -3.0074905166802637
#         dur: 1000; easing: linear; loop: false; delay:0.599" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.2988420049934575 -1 -1.9458522008808359"
#     animation="property: position; to:-1.2988420049934575 0.23 -1.9458522008808359
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:-1.2988420049934575 -1 -1.9458522008808359
#         dur: 1000; easing: linear; loop: false; delay:0.688" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.33060038568719397 -1 -2.2393187284724263"
#     animation="property: position; to:0.33060038568719397 0.23 -2.2393187284724263
#     dur: 1000; easing: linear; loop: false; delay:0.603"
#         animation__2="property: position; to:0.33060038568719397 -1 -2.2393187284724263
#         dur: 1000; easing: linear; loop: false; delay:0.687" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.3378879699318531 -1 -2.7585101377535466"
#     animation="property: position; to:-0.3378879699318531 0.23 -2.7585101377535466
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:-0.3378879699318531 -1 -2.7585101377535466
#         dur: 1000; easing: linear; loop: false; delay:0.689" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.3378879699318531 -1 -2.7585101377535466"
#     animation="property: position; to:-0.3378879699318531 0.23 -2.7585101377535466
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:-0.3378879699318531 -1 -2.7585101377535466
#         dur: 1000; easing: linear; loop: false; delay:0.689" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.08238854271148743 -1 -1.1010942380544293"
#     animation="property: position; to:0.08238854271148743 0.23 -1.1010942380544293
#     dur: 1000; easing: linear; loop: false; delay:0.607" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.012220088742833424 -1 -2.627647403820447"
#     animation="property: position; to:-0.012220088742833424 0.23 -2.627647403820447
#     dur: 1000; easing: linear; loop: false; delay:0.603"
#         animation__2="property: position; to:-0.012220088742833424 -1 -2.627647403820447
#         dur: 1000; easing: linear; loop: false; delay:0.611" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.5987147745442598 -1 -3.564864926654991"
#     animation="property: position; to:-0.5987147745442598 0.23 -3.564864926654991
#     dur: 1000; easing: linear; loop: false; delay:0.599" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="0.21184155100472712 -1 -3.3336316674194677"
#     animation="property: position; to:0.21184155100472712 0.23 -3.3336316674194677
#     dur: 1000; easing: linear; loop: false; delay:0.602" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.8903591795285137 -1 -1.2673521520082431"
#     animation="property: position; to:-0.8903591795285137 0.23 -1.2673521520082431
#     dur: 1000; easing: linear; loop: false; delay:0.602" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="1.1201161938600308 -1 -2.9619651182983944"
#     animation="property: position; to:1.1201161938600308 0.23 -2.9619651182983944
#     dur: 1000; easing: linear; loop: false; delay:0.6" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-0.11984265208293432 -1 -0.974112120034988"
#     animation="property: position; to:-0.11984265208293432 0.23 -0.974112120034988
#     dur: 1000; easing: linear; loop: false; delay:0.61" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#church"
#     position="-1.2993063083760716 -1 -1.3500075114425272"
#     animation="property: position; to:-1.2993063083760716 0.23 -1.3500075114425272
#     dur: 1000; easing: linear; loop: false; delay:0.552"  rotation="0 -40 0" scale="0.018 0.036 0.018"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.1043012435026867 -1 -1.0437391497616773"
#     animation="property: position; to:-1.1043012435026867 0.23 -1.0437391497616773
#     dur: 1000; easing: linear; loop: false; delay:0.633"
#         animation__2="property: position; to:-1.1043012435026867 -1 -1.0437391497616773
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#school"
#     position="-0.29221751078621305 -1 -3.4598120160480903"
#     animation="property: position; to:-0.29221751078621305 0.23 -3.4598120160480903
#     dur: 1000; easing: linear; loop: false; delay:0.554"
#         animation__2="property: position; to:-0.29221751078621305 -1 -3.4598120160480903
#         dur: 1000; easing: linear; loop: false; delay:0.624" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="-1.1573775836374807 -1 -3.273569530381792"
#     animation="property: position; to:-1.1573775836374807 0.23 -3.273569530381792
#     dur: 1000; easing: linear; loop: false; delay:0.58" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#building"
#     position="0.4977071319479365 -1 -2.724084439847502"
#     animation="property: position; to:0.4977071319479365 0.23 -2.724084439847502
#     dur: 1000; easing: linear; loop: false; delay:0.532" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.1139607681736379 -1 -0.5880051651984104"
#     animation="property: position; to:-1.1139607681736379 0.23 -0.5880051651984104
#     dur: 1000; easing: linear; loop: false; delay:0.609" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.007865139205659899 -1 -2.545009461151494"
#     animation="property: position; to:-0.007865139205659899 0.23 -2.545009461151494
#     dur: 1000; easing: linear; loop: false; delay:0.627"
#         animation__2="property: position; to:-0.007865139205659899 -1 -2.545009461151494
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.11675094125057517 -1 -3.17032555869082"
#     animation="property: position; to:0.11675094125057517 0.23 -3.17032555869082
#     dur: 1000; easing: linear; loop: false; delay:0.627"
#         animation__2="property: position; to:0.11675094125057517 -1 -3.17032555869082
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="-1.2988420049934575 -1 -1.9458522008808359"
#     animation="property: position; to:-1.2988420049934575 0.23 -1.9458522008808359
#     dur: 1000; easing: linear; loop: false; delay:0.598"
#         animation__2="property: position; to:-1.2988420049934575 -1 -1.9458522008808359
#         dur: 1000; easing: linear; loop: false; delay:0.688" scale="0.02 0.02 0.02"></a-entity>
# <a-entity gltf-model="#building"
#     position="1.0277263889486676 -1 -3.249764066253192"
#     animation="property: position; to:1.0277263889486676 0.23 -3.249764066253192
#     dur: 1000; easing: linear; loop: false; delay:0.599"
#         animation__2="property: position; to:1.0277263889486676 -1 -3.249764066253192
#         dur: 1000; easing: linear; loop: false; delay:0.609" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#health_institution"
#     position="-0.8792486423141781 -1 -2.118019104365885"
#     animation="property: position; to:-0.8792486423141781 0.23 -2.118019104365885
#     dur: 1000; easing: linear; loop: false; delay:0.477" scale="0.05 0.05 0.05"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.4548623619651153 -1 -2.7115129002522735"
#     animation="property: position; to:0.4548623619651153 0.23 -2.7115129002522735
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:0.4548623619651153 -1 -2.7115129002522735
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.2971467043482334 -1 -2.8135642601719155"
#     animation="property: position; to:-0.2971467043482334 0.23 -2.8135642601719155
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-0.2971467043482334 -1 -2.8135642601719155
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.1947209641431982 -1 -2.70698979215922"
#     animation="property: position; to:-1.1947209641431982 0.23 -2.70698979215922
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-1.1947209641431982 -1 -2.70698979215922
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.8034666855630348 -1 -2.33412690615296"
#     animation="property: position; to:-0.8034666855630348 0.23 -2.33412690615296
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-0.8034666855630348 -1 -2.33412690615296
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.7558693020475402 -1 -2.332430766797188"
#     animation="property: position; to:-0.7558693020475402 0.23 -2.332430766797188
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-0.7558693020475402 -1 -2.332430766797188
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.3898770291068103 -1 -0.8936489627831179"
#     animation="property: position; to:-0.3898770291068103 0.23 -0.8936489627831179
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-0.3898770291068103 -1 -0.8936489627831179
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="0.7735651546466216 -1 -3.256549065294166"
#     animation="property: position; to:0.7735651546466216 0.23 -3.256549065294166
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:0.7735651546466216 -1 -3.256549065294166
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-0.010329584271585146 -1 -2.5444440640549146"
#     animation="property: position; to:-0.010329584271585146 0.23 -2.5444440640549146
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-0.010329584271585146 -1 -2.5444440640549146
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.1078440441089696 -1 -1.70178024852612"
#     animation="property: position; to:-1.1078440441089696 0.23 -1.70178024852612
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:-1.1078440441089696 -1 -1.70178024852612
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="-0.6432680401719153 -1 -2.081976467938148"
#     animation="property: position; to:-0.6432680401719153 0.23 -2.081976467938148
#     dur: 1000; easing: linear; loop: false; delay:0.466"
#         animation__2="property: position; to:-0.6432680401719153 -1 -2.081976467938148
#         dur: 1000; easing: linear; loop: false; delay:0.539" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.4486788333208096 -1 -2.908398129402485"
#     animation="property: position; to:-0.4486788333208096 0.23 -2.908398129402485
#     dur: 1000; easing: linear; loop: false; delay:0.668" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="0.5181716393147326 -1 -3.050179153429781"
#     animation="property: position; to:0.5181716393147326 0.23 -3.050179153429781
#     dur: 1000; easing: linear; loop: false; delay:-0.109"
#         animation__2="property: position; to:0.5181716393147326 -1 -3.050179153429781
#         dur: 1000; easing: linear; loop: false; delay:0.539" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="1.2623248699972465 -1 -2.8870641169851297"
#     animation="property: position; to:1.2623248699972465 0.23 -2.8870641169851297
#     dur: 1000; easing: linear; loop: false; delay:0.631"
#         animation__2="property: position; to:1.2623248699972465 -1 -2.8870641169851297
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#park"
#     position="0.9827117891784838 -1 -3.327219947688718"
#     animation="property: position; to:0.9827117891784838 0.23 -3.327219947688718
#     dur: 1000; easing: linear; loop: false; delay:0.554" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#NS_institution"
#     position="-1.6392720555670166 -1 -3.107566599635902"
#     animation="property: position; to:-1.6392720555670166 0.23 -3.107566599635902
#     dur: 1000; easing: linear; loop: false; delay:0.627"
#         animation__2="property: position; to:-1.6392720555670166 -1 -3.107566599635902
#         dur: 1000; easing: linear; loop: false; delay:0.634" scale="0"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="0.5565268702137474 -1 -1.395086299151444"
#     animation="property: position; to:0.5565268702137474 0.23 -1.395086299151444
#     dur: 1000; easing: linear; loop: false; delay:0.117"
#         animation__2="property: position; to:0.5565268702137474 -1 -1.395086299151444
#         dur: 1000; easing: linear; loop: false; delay:0.539" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.6637606967130523 -1 -1.4131354628971167"
#     animation="property: position; to:-0.6637606967130523 0.23 -1.4131354628971167
#     dur: 1000; easing: linear; loop: false; delay:0.702" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#park"
#     position="0.9965766176776925 -1 -2.62865700182374"
#     animation="property: position; to:0.9965766176776925 0.23 -2.62865700182374
#     dur: 1000; easing: linear; loop: false; delay:0.681" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="-0.024500988933323198 -1 -2.4576596895203693"
#     animation="property: position; to:-0.024500988933323198 0.23 -2.4576596895203693
#     dur: 1000; easing: linear; loop: false; delay:0.229"
#         animation__2="property: position; to:-0.024500988933323198 -1 -2.4576596895203693
#         dur: 1000; easing: linear; loop: false; delay:0.539" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#park"
#     position="-0.5195984981830406 -1 -2.2622148418631696"
#     animation="property: position; to:-0.5195984981830406 0.23 -2.2622148418631696
#     dur: 1000; easing: linear; loop: false; delay:0.593"
#         animation__2="property: position; to:-0.5195984981830406 -1 -2.2622148418631696
#         dur: 1000; easing: linear; loop: false; delay:0.617" scale="0.005 0.005 0.005"></a-entity>
# <a-entity gltf-model="#settlement"
#     position="-0.2583293413301362 -1 -3.1431866244729463"
#     animation="property: position; to:-0.2583293413301362 0.23 -3.1431866244729463
#     dur: 1000; easing: linear; loop: false; delay:0.004"
#         animation__2="property: position; to:-0.2583293413301362 -1 -3.1431866244729463
#         dur: 1000; easing: linear; loop: false; delay:0.539" scale="0.2 0.2 0.2"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.0021483762136995654 -1 -2.082768009568099"
#     animation="property: position; to:0.0021483762136995654 0.23 -2.082768009568099
#     dur: 1000; easing: linear; loop: false; delay:0.576" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.7723591048245908 -1 -2.765829985441087"
#     animation="property: position; to:0.7723591048245908 0.23 -2.765829985441087
#     dur: 1000; easing: linear; loop: false; delay:0.698" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.6568050040657909 -1 -2.7748354133073008"
#     animation="property: position; to:0.6568050040657909 0.23 -2.7748354133073008
#     dur: 1000; easing: linear; loop: false; delay:0.555"
#         animation__2="property: position; to:0.6568050040657909 -1 -2.7748354133073008
#         dur: 1000; easing: linear; loop: false; delay:0.573" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="-1.2353867462517882 -1 -2.381334961277389"
#     animation="property: position; to:-1.2353867462517882 0.23 -2.381334961277389
#     dur: 1000; easing: linear; loop: false; delay:0.566"
#         animation__2="property: position; to:-1.2353867462517882 -1 -2.381334961277389
#         dur: 1000; easing: linear; loop: false; delay:0.645" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="-0.031124555493715844 -1 -1.8100433146391879"
#     animation="property: position; to:-0.031124555493715844 0.23 -1.8100433146391879
#     dur: 1000; easing: linear; loop: false; delay:0.553"
#         animation__2="property: position; to:-0.031124555493715844 -1 -1.8100433146391879
#         dur: 1000; easing: linear; loop: false; delay:0.58" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="-1.1573775836374807 -1 -3.273569530381792"
#     animation="property: position; to:-1.1573775836374807 0.23 -3.273569530381792
#     dur: 1000; easing: linear; loop: false; delay:0.576" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#school"
#     position="0.1527957548594714 -1 -2.0828244044569146"
#     animation="property: position; to:0.1527957548594714 0.23 -2.0828244044569146
#     dur: 1000; easing: linear; loop: false; delay:0.572"
#         animation__2="property: position; to:0.1527957548594714 -1 -2.0828244044569146
#         dur: 1000; easing: linear; loop: false; delay:0.646" scale="0.006 0.006 0.006"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.5853575007765357 -1 -3.6459103205907013"
#     animation="property: position; to:-1.5853575007765357 0.23 -3.6459103205907013
#     dur: 1000; easing: linear; loop: false; delay:0.614" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#building"
#     position="-1.5786541219974424 -1 -3.2634788297691557"
#     animation="property: position; to:-1.5786541219974424 0.23 -3.2634788297691557
#     dur: 1000; easing: linear; loop: false; delay:0.614" scale="0.003 0.003 0.003"></a-entity>
# <a-entity gltf-model="#cinema"
#     position="1.700000000000091 -1 -2.0655371346947504"
#     animation="property: position; to:1.700000000000091 0.23 -2.0655371346947504
#     dur: 1000; easing: linear; loop: false; delay:0.602" scale="0.02 0.02 0.02"></a-entity>
